# %%
# !pip install transformers accelerate gradio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 MB 28.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.8/319.8 kB 17.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.7/94.7 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 83.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.3/73.3 kB 5.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tomlkit
#     Found existing installation: tomlkit 0.13.2
#     Uninstalling tomlkit-0.13.2:
#       Successfully uninstalled tomlkit-0.13.2
#   Attempting uninstall: python-multipart
#     Found existing installation: python-multipart 0.0.9
#     Uninstalling python-multipart-0.0.9:
#       Successfully uninstalled python-multipart-0.0.9
#   Attempting uninstall: starlette
#     Found existing installation: starlette 0.37.2
#     Uninstalling starlette-0.37.2:
#       Successfully uninstalled starlette-0.37.2
#   Attempting uninstall: fastapi
# ...

# %% [markdown]
# **Importing the Dependencies**

# %%
import os

from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

# %%
os.environ["HF_TOKEN"] = "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"

# %%
model_name = "google/gemma-2b-it"

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# tokenizer_config.json:   0%|          | 0.00/34.2k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]

# %%
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.bfloat16,
    device_map="auto"
)
# Out:
# config.json:   0%|          | 0.00/627 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/13.5k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/67.1M [00:00<?, ?B/s]
# `config.hidden_act` is ignored, you should use `config.hidden_activation` instead.
# Gemma's activation function will be set to `gelu_pytorch_tanh`. Please, use
# `config.hidden_activation` if you want to override this behaviour.
# See https://github.com/huggingface/transformers/pull/29402 for more details.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]

# %% [markdown]
# **Invoke the LLM**

# %%
def Invoke(input_text):
    input_ids = tokenizer(input_text, return_tensors="pt").to("cuda")
    response = model.generate(**input_ids, max_new_tokens=512)
    output = tokenizer.decode(response[0], skip_special_tokens=True)
    print(output)

# %%
input_text = "Write about Machine Learning"
Invoke(input_text)
# Out:
# Starting from v4.46, the `logits` model output will have the same type as the model (except at train time, where it will always be FP32)
# Write about Machine Learning and its applications.
#
# ## Machine Learning: A Powerful Tool for Innovation
#
# Machine learning (ML) is a rapidly evolving field of computer science that allows computers to learn from data without explicit programming. This allows machines to perform tasks that would be difficult or impossible for humans, such as image recognition, natural language processing, and self-driving cars.
#
# **Key Concepts of Machine Learning:**
#
# * **Data:** ML algorithms are trained on vast datasets to identify patterns and relationships.
# * **Algorithms:** Different algorithms, such as supervised learning, unsupervised learning, and reinforcement learning, are used to analyze data and make predictions.
# * **Model:** A trained algorithm is used to make predictions or decisions based on new data.
#
# ...

# %%
input_text = "Write a about AI"
Invoke(input_text)
# Out:
# Write a about AI and its impact on society.
#
# Artificial intelligence (AI) is a rapidly developing field that has the potential to revolutionize many aspects of human life. AI refers to the ability of a machine to perform tasks that typically require human intelligence, such as learning, problem-solving, and decision-making.
#
# **Impact on Society:**
#
# **1. Automation and Job Market:**
# - AI can automate many tasks currently performed by humans, such as data entry, customer service, and manufacturing.
# - This can lead to job losses in certain sectors, but it also creates new opportunities in areas such as AI development, data science, and robotics.
#
# **2. Enhanced Healthcare:**
# - AI can be used to analyze medical data, identify diseases, and develop personalized treatments.
# - This can lead to improved patient outcomes and reduced healthcare costs.
#
# **3. Improved Transportation:**
# ...

# %%
input_text = "what is NLP and why to use in life application?"
Invoke(input_text)
# Out:
# what is NLP and why to use in life application?
#
# **Natural Language Processing (NLP)** is a branch of artificial intelligence (AI) that focuses on enabling computers to understand, interpret, and generate human language. NLP encompasses a wide range of techniques and algorithms, including machine learning, deep learning, and statistical modeling.
#
# **Why NLP is important in life applications:**
#
# * **Enhanced communication:** NLP can be used to develop chatbots and virtual assistants that can provide personalized and contextual responses, improving communication efficiency and customer satisfaction.
# * **Automated tasks:** NLP can automate various tasks, such as data entry, transcription, and sentiment analysis, freeing up human resources for more complex and creative work.
# * **Personalized recommendations:** NLP can analyze user behavior and preferences to provide customized recommendations and suggestions, enhancing the user experience.
# ...

# %%
input_text = "provide summary for deep learning"
Invoke(input_text)
# Out:
# provide summary for deep learning models.
#
# **Deep Learning Models**
#
# **Definition:**
# Deep learning models are a type of machine learning that uses artificial neural networks (ANNs) to learn from data. These models are inspired by the structure and function of the human brain, with multiple layers of interconnected nodes that process and transmit information.
#
# **Key Concepts:**
#
# * **Artificial Neural Networks (ANNs):** Deep learning models are built using artificial neural networks, which are interconnected layers of nodes that learn to represent data.
# * **Layers:** Deep learning models are divided into multiple layers, each with a specific function. The input layer receives raw data, and the output layer produces the final prediction or output.
# * **Connections:** Nodes in different layers are connected by weights, which are learned during the training process. These weights determine the strength of the relationships between input and output variables.
# ...

# %%
input_text = "What is LLM?"
Invoke(input_text)
# Out:
# What is LLM?
#
# LLM stands for Large Language Model. It is a type of artificial intelligence (AI) that has been trained on a massive dataset of text and code. This allows them to perform a wide range of natural language processing (NLP) tasks, such as language translation, text summarization, and question answering.

# %% [markdown]
# **Deploy LLM with Gradio as API**

# %%
import json
import gradio as gr

# %%
def get_response(input_data):
    input_data = json.loads(input_data)
    input_text = input_data["query"]
    input_ids = tokenizer(input_text, return_tensors="pt").to("cuda")
    response = model.generate(**input_ids, max_new_tokens=512)
    output = tokenizer.decode(response[0], skip_special_tokens=True)
    return {"output": output}

# %%
demo = gr.Interface(
    fn=get_response,
    inputs="json",
    outputs="json"
)

#demo.queue().launch(share=True, debug=True, show_error=True)

# %%
#### بس كدة يا لذيذ
