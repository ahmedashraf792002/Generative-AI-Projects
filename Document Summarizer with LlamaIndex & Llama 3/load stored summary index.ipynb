# %%
import os
import json

# %%
config_data = json.load(open("config.json"))
GROQ_API_KEY = config_data["api_key"]
os.environ["GROQ_API_KEY"] = GROQ_API_KEY

# %%
os.environ["GROQ_API_KEY"] = GROQ_API_KEY

# %%
import nest_asyncio

nest_asyncio.apply()

# %%
from llama_index.core import load_index_from_storage
from llama_index.core import StorageContext
from llama_index.llms.groq import Groq
from llama_index.core import Settings
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
# Out:
# WARNING:tensorflow:From D:\Taskes\Project\New folder\New folder\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
llm = Groq(model="llama-3.1-8b-instant")

Settings.llm = llm
Settings.embed_model = HuggingFaceEmbedding()

# %%
storage_context = StorageContext.from_defaults(persist_dir="doc_summary_index")

summary_index = load_index_from_storage(storage_context)

# %%
summary_query_engine = summary_index.as_query_engine(
    response_mode="tree_summarize",
    use_async=True
)

# %%
response = summary_query_engine.query("Give a detailed summary of teh given document")

print(response)
# Out:
# The document discusses various concepts and techniques related to unsupervised learning, specifically clustering. It begins by introducing the concept of clustering, which is a method of grouping similar data points into clusters. Clustering is a type of unsupervised learning where the algorithm is not provided with labeled data, and it is left to discover patterns and relationships within the data on its own.
#
# The document explains that clustering is useful for identifying patterns and relationships within the data, and it has many real-world applications, such as customer segmentation, text clustering, and image segmentation. Clustering is often called an unsupervised learning task as no class values denoting an a priori grouping of the data instances are given.
#
# The document then focuses on the K-means algorithm, a popular clustering algorithm that partitions the given data into k clusters. The algorithm works by randomly choosing k data points (seeds) to be the initial centroids, assigning each data point to the closest centroid, re-computing the centroids using the current cluster memberships, and repeating the process until a convergence criterion is met.
#
# However, the document highlights the strengths and weaknesses of the K-means algorithm. The strengths include its simplicity, efficiency, and popularity. However, the algorithm is sensitive to initial seeds, outliers, and the number of clusters (k). It is also not suitable for discovering clusters that are not hyper-ellipsoids (or hyper-spheres).
#
# In addition to the K-means algorithm, the document introduces hierarchical clustering, a type of clustering that produces a nested sequence of clusters, a tree, also called a Dendrogram. Hierarchical clustering can be performed using either agglomerative (bottom-up) or divisive (top-down) methods. The document explains that agglomerative clustering is more popular than divisive methods and involves merging nodes/clusters that have the least distance.
#
# The document also discusses various distance functions, which are essential for clustering. It explains that there are various distance functions for different types of data, including numeric, binary, and nominal attributes. The document provides examples of distance functions for each type of attribute, including Euclidean distance, Manhattan distance, and cosine similarity.
#
# Furthermore, the document touches on data standardization, which is the process of transforming attributes to have equal impact on the computation of distances. It explains that interval-scaled attributes can be standardized using range and z-score methods, while ratio-scaled attributes can be transformed using log functions.
#
# The document also discusses the challenges of dealing with mixed attributes, which are attributes of different types, such as interval-scaled, symmetric binary, asymmetric binary, ratio-scaled, ordinal, and nominal. It explains that one common way to deal with mixed attributes is to convert them to a single type, such as interval-scaled, and provides examples of how to do this.
#
# In addition, the document discusses the concept of ground truth, which is a set of labeled data used to evaluate the quality of a clustering. It explains that ground truth is used to construct a confusion matrix, which is used to compute various measurements, such as entropy, purity, precision, recall, and F-score.
#
# The document also discusses the concept of indirect evaluation, which is used to evaluate the quality of a clustering based on its performance on a primary task. It provides an example of how to use indirect evaluation to compare clustering methods.
#
# Finally, the document discusses the computation of entropy, which is a critical step in decision tree building. It explains that entropy can be evaluated without adding N points and provides an example of how to compute entropy using the number of Y points and the number of N points.
#
# Overall, the document provides a comprehensive overview of various concepts and techniques related to unsupervised learning, specifically clustering. It highlights the importance of clustering in practice and the need for more research in this area.
